# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
f1=pd.read_csv('companies (1).txt',sep="\t")

# %%
f1
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# ...                                                  ...
# 66363  /Organization/Zznode-Science-And-Technology-Co...
# 66364                          /Organization/Zzzzapp-Com
# 66365                               /Organization/ÃEron
# 66366                             /Organization/Ã”Asys-2
# 66367  /Organization/Ä°Novatiff-Reklam-Ve-Tanä±Tä±M-H...
#
#                                                 name  \
# 0                                              #fame
# 1                                           :Qounter
# 2                             (THE) ONE of THEM,Inc.
# 3                                            0-6.com
# ...

# %%
f1.shape
# Out:
# (66368, 10)

# %%
f1.columns
# Out:
# Index(['permalink', 'name', 'homepage_url', 'category_list', 'status',
#        'country_code', 'state_code', 'region', 'city', 'founded_at'],
#       dtype='object')

# %%
f2 = pd.read_csv('rounds2.csv', encoding='latin-1') 
f2
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# ...                                                   ...
# 114944                          /organization/zzzzapp-com
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                               /organization/ãeron
# 114947                             /ORGANIZATION/ÃASYS-2
# 114948  /organization/ä°novatiff-reklam-ve-tanä±tä±m-h...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %%
f2.columns
# Out:
# Index(['company_permalink', 'funding_round_permalink', 'funding_round_type',
#        'funding_round_code', 'funded_at', 'raised_amount_usd'],
#       dtype='object')

# %%
f2['company_permalink'].nunique()
# Out:
# 90247

# %%
f1['name'].nunique()
# Out:
# 66102

# %% [markdown]
#  <-q3 done

# %%
f2['company_permalink']=f2['company_permalink'].str.upper()
f2
# Out:
#                                         company_permalink  \
# 0                                     /ORGANIZATION/-FAME
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /ORGANIZATION/-QOUNTER
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /ORGANIZATION/0-6-COM
# ...                                                   ...
# 114944                          /ORGANIZATION/ZZZZAPP-COM
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                               /ORGANIZATION/ÃERON
# 114947                             /ORGANIZATION/ÃASYS-2
# 114948  /ORGANIZATION/Ä°NOVATIFF-REKLAM-VE-TANÄ±TÄ±M-H...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %%
f1['permalink']=f1['permalink'].str.upper()
f1
# Out:
#                                                permalink  \
# 0                                    /ORGANIZATION/-FAME
# 1                                 /ORGANIZATION/-QOUNTER
# 2                    /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 3                                  /ORGANIZATION/0-6-COM
# 4                         /ORGANIZATION/004-TECHNOLOGIES
# ...                                                  ...
# 66363  /ORGANIZATION/ZZNODE-SCIENCE-AND-TECHNOLOGY-CO...
# 66364                          /ORGANIZATION/ZZZZAPP-COM
# 66365                               /ORGANIZATION/ÃERON
# 66366                             /ORGANIZATION/Ã”ASYS-2
# 66367  /ORGANIZATION/Ä°NOVATIFF-REKLAM-VE-TANÄ±TÄ±M-H...
#
#                                                 name  \
# 0                                              #fame
# 1                                           :Qounter
# 2                             (THE) ONE of THEM,Inc.
# 3                                            0-6.com
# ...

# %% [markdown]
# <-q4 done

# %%
count=0
for value in f2['company_permalink']:
    p=value in f1['permalink'] 
    if p==True:
        count+=1

print (count)
# Out:
# 0

# %% [markdown]
# q5 done

# %%
f2
# Out:
#                                         company_permalink  \
# 0                                     /ORGANIZATION/-FAME
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /ORGANIZATION/-QOUNTER
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /ORGANIZATION/0-6-COM
# ...                                                   ...
# 114944                          /ORGANIZATION/ZZZZAPP-COM
# 114945                          /ORGANIZATION/ZZZZAPP-COM
# 114946                               /ORGANIZATION/ÃERON
# 114947                             /ORGANIZATION/ÃASYS-2
# 114948  /ORGANIZATION/Ä°NOVATIFF-REKLAM-VE-TANÄ±TÄ±M-H...
#
#                                 funding_round_permalink funding_round_type  \
# 0       /funding-round/9a01d05418af9f794eebff7ace91f638            venture
# 1       /funding-round/22dacff496eb7acb2b901dec1dfe5633            venture
# ...

# %%
f2['company_permalink'].isin(f1['permalink'])
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 114944     True
# 114945     True
# 114946     True
# 114947    False
# 114948     True
# Name: company_permalink, Length: 114949, dtype: bool

# %% [markdown]
# q6

# %%
master_dataframe=pd.merge(f1,f2,left_on='permalink',right_on='company_permalink', how='outer')
master_dataframe
# Out:
#                                                 permalink  \
# 0                                     /ORGANIZATION/-FAME
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /ORGANIZATION/-QOUNTER
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /ORGANIZATION/0-6-COM
# ...                                                   ...
# 114971                          /ORGANIZATION/ZZZZAPP-COM
# 114972                               /ORGANIZATION/ÃERON
# 114973                                                NaN
# 114974                             /ORGANIZATION/Ã”ASYS-2
# 114975  /ORGANIZATION/Ä°NOVATIFF-REKLAM-VE-TANÄ±TÄ±M-H...
#
#                                                  name            homepage_url  \
# 0                                               #fame      http://livfame.com
# 1                                            :Qounter  http://www.qounter.com
# ...

# %%
master_dataframe.drop('company_permalink',axis=1,inplace=True)

# %%
master_dataframe.isna().sum()/len(master_dataframe)*100
# Out:
# permalink                   0.027832
# name                        0.028702
# homepage_url                5.362858
# category_list               2.992798
# status                      0.027832
# country_code                7.571145
# state_code                  9.543731
# region                      8.866198
# city                        8.863589
# founded_at                 17.875905
# funding_round_permalink     0.023483
# funding_round_type          0.023483
# funding_round_code         72.916087
# funded_at                   0.023483
# raised_amount_usd          17.409720
# dtype: float64

# %% [markdown]
# <-q8 done

# %%
filtered_df = master_dataframe[
    (master_dataframe['raised_amount_usd'] >= 4_000_000) &
    (master_dataframe['raised_amount_usd'] <= 15_000_000)
]

print(filtered_df)
# Out:
#                                        permalink                         name  \
# 0                            /ORGANIZATION/-FAME                        #fame
# 12                          /ORGANIZATION/0XDATA                       H2O.ai
# 21      /ORGANIZATION/1-800-PUBLICRELATIONS-INC-  1-800-PublicRelations, Inc.
# 22                    /ORGANIZATION/1-MAINSTREAM                 1 Mainstream
# 28                 /ORGANIZATION/10-MINUTES-WITH              10 Minutes With
# ...                                          ...                          ...
# 114947                  /ORGANIZATION/ZYOMYX-INC                       ZYOMYX
# 114948                  /ORGANIZATION/ZYOMYX-INC                       ZYOMYX
# 114956            /ORGANIZATION/ZYRAZ-TECHNOLOGY             Zyraz Technology
# 114957            /ORGANIZATION/ZYRAZ-TECHNOLOGY             Zyraz Technology
# 114962                      /ORGANIZATION/ZYSTOR                       Zystor
#
# ...

# %% [markdown]
# <- q 1o done

# %%
venture_df = master_dataframe[master_dataframe['funding_round_type'] == 'venture']


country_investment = venture_df.groupby('country_code')['raised_amount_usd'].sum()


top_9_countries = country_investment.sort_values(ascending=False).head(9)


print(top_9_countries)
# Out:
# country_code
# USA    4.225108e+11
# CHN    3.983542e+10
# GBR    2.024563e+10
# IND    1.439186e+10
# CAN    9.583332e+09
# FRA    7.259537e+09
# ISR    6.907515e+09
# DEU    6.346960e+09
# JPN    3.363677e+09
# Name: raised_amount_usd, dtype: float64

# %% [markdown]
# <- q11 done

# %%
master_dataframe['main_category'] = master_dataframe['category_list'].str.split('|').str[0]

print(master_dataframe[['category_list', 'main_category']])
# Out:
#                                             category_list  \
# 0                                                   Media
# 1       Application Platforms|Real Time|Social Network...
# 2       Application Platforms|Real Time|Social Network...
# 3                                       Apps|Games|Mobile
# 4                                             Curated Web
# ...                                                   ...
# 114971        Advertising|Mobile|Web Development|Wireless
# 114972                                                NaN
# 114973                                                NaN
# 114974  Consumer Electronics|Internet of Things|Teleco...
# 114975                 Consumer Goods|E-Commerce|Internet
#
#                 main_category
# 0                       Media
# 1       Application Platforms
# 2       Application Platforms
# 3                        Apps
# 4                 Curated Web
# ...                       ...
# 114971            Advertising
# ...

# %%
def x1(a):
    if a>7000000:
        return 'type C'
    elif a<5000000:
        return 'type a'
    else:
        return 'type b'

# %%
master_dataframe['typeclass']= master_dataframe['raised_amount_usd'].map(x1)
master_dataframe['typeclass']
# Out:
# 0         type C
# 1         type b
# 2         type a
# 3         type a
# 4         type a
#            ...
# 114971    type a
# 114972    type b
# 114973    type a
# 114974    type b
# 114975    type a
# Name: typeclass, Length: 114976, dtype: object

# %%
pd.pivot_table(master_dataframe,index='funding_round_type',values='raised_amount_usd',aggfunc=['mean','median'])
# Out:
#                                    mean            median
#                       raised_amount_usd raised_amount_usd
# funding_round_type
# angel                      9.586945e+05          400000.0
# convertible_note           1.453439e+06          272000.0
# debt_financing             1.704353e+07         1100000.0
# equity_crowdfunding        5.383682e+05          100000.0
# grant                      4.300576e+06          201684.0
# non_equity_assistance      4.112031e+05           60000.0
# post_ipo_debt              1.687046e+08        19950000.0
# post_ipo_equity            8.218249e+07        12262852.5
# private_equity             7.330859e+07        20000000.0
# product_crowdfunding       1.363131e+06          183915.0
# secondary_market           7.964963e+07        32600000.0
# seed                       7.198180e+05          275000.0
# undisclosed                1.924237e+07         1018680.0
# venture                    1.174895e+07         5000000.0
